# %%
# ================================================================
# Single Colab cell: Download images from Drive folder ID, remove balls, save outputs, zip & download
# ================================================================

# Install / upgrade required libs
# !pip install -q --upgrade ultralytics opencv-python-headless google-api-python-client google-auth-httplib2 google-auth-oauthlib

import os
import io
import zipfile
import cv2
import numpy as np
from ultralytics import YOLO
from google.colab import auth, files
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload, MediaIoBaseUpload
from oauth2client.client import GoogleCredentials

# ---------------- CONFIG ----------------
FOLDER_ID = "1m36zN0wauHii_b8kNk6ORS7dG-F-rcxv"  # <- your Drive folder id
LOCAL_INPUT = "/content/input_images"
LOCAL_OUTPUT = "/content/output_images"
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/ball_removed_results"  # where to save outputs in your Drive
ZIP_PATH = "/content/removed_images.zip"
VALID_EXT = (".jpg", ".jpeg", ".png")

os.makedirs(LOCAL_INPUT, exist_ok=True)
os.makedirs(LOCAL_OUTPUT, exist_ok=True)
os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)

# ---------------- Authenticate & build Drive service ----------------
print("Authenticating (you will be prompted)...")
auth.authenticate_user()
creds = GoogleCredentials.get_application_default()
service = build('drive', 'v3', credentials=creds, cache_discovery=False)
print("Drive API ready.")

# ---------------- List files in folder ----------------
print(f"Listing files in folder id: {FOLDER_ID} ...")
resp = service.files().list(q=f"'{FOLDER_ID}' in parents and trashed=false",
                            fields="files(id, name, mimeType)").execute()
items = resp.get('files', [])
if not items:
    raise SystemExit("No files found in that Drive folder (or you don't have access).")

# ---------------- Download image files to local input ----------------
downloaded = 0
for f in items:
    name = f['name']
    fid = f['id']
    lname = name.lower()
    if not lname.endswith(VALID_EXT):
        print("Skipping (not image):", name)
        continue
    out_path = os.path.join(LOCAL_INPUT, name)
    print("Downloading:", name)
    request = service.files().get_media(fileId=fid)
    fh = io.FileIO(out_path, mode='wb')
    downloader = MediaIoBaseDownload(fh, request)
    done = False
    while not done:
        status, done = downloader.next_chunk()
    fh.close()
    downloaded += 1

print(f"Downloaded {downloaded} images to {LOCAL_INPUT}")
if downloaded == 0:
    raise SystemExit("No images downloaded. Ensure the folder contains JPG/PNG images and you have access.")

# ---------------- Load YOLO model ----------------
print("Loading YOLO model (may download weights)...")
try:
    model = YOLO("yolov8x-seg.pt")
except Exception as e:
    print("Could not load local weights ('yolov8x-seg.pt'), falling back to alias.")
    model = YOLO("yolov8x-seg")  # ultralytics may auto-download

names = getattr(model.model, "names", {})
ball_classes = [k for k,v in names.items() if "ball" in v.lower()]
print("ball_classes (detected by name):", ball_classes)

# ---------------- Helper funcs ----------------
def refine_mask(mask):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7,7))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=1)
    mask = cv2.dilate(mask, kernel, iterations=2)
    mask = cv2.GaussianBlur(mask, (7,7), 0)
    _, mask = cv2.threshold(mask, 50, 255, cv2.THRESH_BINARY)
    return mask

def hough_fallback(img_gray):
    h, w = img_gray.shape
    minR = max(3, min(h,w)//200)
    maxR = max(12, min(h,w)//25)
    circles = cv2.HoughCircles(img_gray, cv2.HOUGH_GRADIENT, dp=1.2, minDist=min(h,w)//10,
                               param1=100, param2=15, minRadius=minR, maxRadius=maxR)
    if circles is None:
        return None
    circles = np.uint16(np.around(circles[0]))
    circles = sorted(circles, key=lambda c: c[2])
    x,y,r = circles[0]
    mask = np.zeros((h,w), dtype=np.uint8)
    cv2.circle(mask, (x,y), r, 255, -1)
    return mask

# ---------------- Process images ----------------
input_files = sorted([f for f in os.listdir(LOCAL_INPUT) if f.lower().endswith(VALID_EXT)])
print("Processing", len(input_files), "images...")

for fname in input_files:
    path = os.path.join(LOCAL_INPUT, fname)
    img = cv2.imread(path)
    if img is None:
        print("Could not read", fname, "- skipping")
        continue
    h, w = img.shape[:2]
    img_area = h*w

    # inference (try to filter by ball class ids if present)
    try:
        if ball_classes:
            res = model(img, classes=ball_classes, conf=0.25, iou=0.45)[0]
        else:
            res = model(img, conf=0.25, iou=0.45)[0]
    except Exception as e:
        print("Inference error with class filter:", e, "-> retrying without class filter")
        res = model(img)[0]

    chosen_mask = None
    if getattr(res, "masks", None) is not None:
        try:
            masks_arr = res.masks.data.cpu().numpy()
        except Exception:
            # fallbacks for API variants
            try:
                masks_arr = np.array([m.numpy() for m in res.masks])
            except Exception:
                masks_arr = None
        if masks_arr is not None:
            best_area = img_area
            for m in masks_arr:
                binm = (m > 0.5).astype(np.uint8)
                area = binm.sum()
                area_ratio = area / img_area
                ys, xs = np.where(binm > 0)
                if xs.size == 0 or ys.size == 0:
                    continue
                aspect_ratio = (np.max(xs)-np.min(xs)) / (np.max(ys)-np.min(ys) + 1e-5)
                if 0.00001 < area_ratio < 0.015 and 0.7 < aspect_ratio < 1.3:
                    if area < best_area:
                        best_area = area
                        chosen_mask = (binm * 255).astype(np.uint8)
            if chosen_mask is not None:
                chosen_mask = cv2.resize(chosen_mask, (w, h), interpolation=cv2.INTER_NEAREST)

    # Hough fallback
    if chosen_mask is None:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray_blur = cv2.GaussianBlur(gray, (7,7), 1.5)
        hm = hough_fallback(gray_blur)
        if hm is not None:
            chosen_mask = hm
            print(f"{fname}: Hough fallback used")
        else:
            print(f"{fname}: No ball detected - skipping")
            continue

    mask = refine_mask(chosen_mask)
    inpaint_mask = (mask > 0).astype(np.uint8) * 255

    # Inpaint Telea -> NS
    t1 = cv2.inpaint(img, inpaint_mask, 3, cv2.INPAINT_TELEA)
    t2 = cv2.inpaint(t1, inpaint_mask, 3, cv2.INPAINT_NS)
    out_img = t2

    # small border blend
    border = cv2.Canny(inpaint_mask, 50, 150)
    if border.sum() > 0:
        blurred = cv2.GaussianBlur(out_img, (5,5), 0)
        border3 = np.repeat((border>0)[:,:,None], 3, axis=2)
        out_img = np.where(border3, blurred, out_img)

    out_name = "removed_" + fname
    local_out_path = os.path.join(LOCAL_OUTPUT, out_name)
    drive_out_path = os.path.join(DRIVE_OUTPUT_DIR, out_name)

    cv2.imwrite(local_out_path, out_img)
    # Write to Drive output folder using Drive API (upload) so path is robust
    # First upload local file to Drive_OUTPUT_DIR by creating a file in MyDrive and uploading content
    # We will try writing directly to the mounted Drive path (if available) first:
    try:
        cv2.imwrite(drive_out_path, out_img)
        print(f"{fname}: saved to Drive path {drive_out_path}")
    except Exception as e:
        # Fallback: upload via Drive API into root MyDrive folder with folder id detection
        try:
            # find (or create) folder MyDrive/ball_removed_results and upload file inside it
            # get folder id by searching by name in MyDrive; if not found create it
            q = "name='ball_removed_results' and mimeType='application/vnd.google-apps.folder' and 'root' in parents and trashed=false"
            folder_resp = service.files().list(q=q, fields="files(id, name)").execute()
            folders = folder_resp.get('files', [])
            if folders:
                out_folder_id = folders[0]['id']
            else:
                file_metadata = {'name': 'ball_removed_results', 'mimeType': 'application/vnd.google-apps.folder'}
                created = service.files().create(body=file_metadata, fields='id').execute()
                out_folder_id = created.get('id')
            # Upload file
            media = MediaIoBaseUpload(io.FileIO(local_out_path, 'rb'), mimetype='image/png')
            file_metadata = {'name': out_name, 'parents': [out_folder_id]}
            service.files().create(body=file_metadata, media_body=media, fields='id').execute()
            print(f"{fname}: uploaded to Drive folder id {out_folder_id} via API")
        except Exception as e2:
            print(f"{fname}: failed to save to Drive by both methods: {e} / {e2}")
            # still local file exists

    print(f"{fname}: processed -> {local_out_path}")

# ---------------- Zip outputs and prompt download ----------------
print("Zipping outputs...")
with zipfile.ZipFile(ZIP_PATH, 'w', zipfile.ZIP_DEFLATED) as zf:
    for root, _, files_in in os.walk(LOCAL_OUTPUT):
        for f in files_in:
            zf.write(os.path.join(root, f), arcname=f)

print("Created ZIP:", ZIP_PATH)
print("Starting browser download (you will be prompted)...")
files.download(ZIP_PATH)

print("All done. Processed images are saved locally in", LOCAL_OUTPUT, "and attempts to save to Drive folder:", DRIVE_OUTPUT_DIR)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.3/221.3 kB 8.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.41.1 which is incompatible.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Authenticating (you will be prompted)...
# Drive API ready.
# Listing files in folder id: 1m36zN0wauHii_b8kNk6ORS7dG-F-rcxv ...
# Downloading: IMG-20251210-WA0027.jpg
# Downloading: IMG-20251210-WA0025.jpg
# Downloading: IMG-20251210-WA0026.jpg
# Downloading: IMG-20251210-WA0022.jpg
# Downloading: IMG-20251210-WA0023.jpg
# Downloading: IMG-20251210-WA0024.jpg
# Downloading: IMG-20251210-WA0021.jpg
# Downloading: IMG-20251210-WA0020.jpg
# Downloading: IMG-20251210-WA0018.jpg
# Downloading: IMG-20251210-WA0019.jpg
# Downloading: IMG-20251210-WA0016.jpg
# Downloading: IMG-20251210-WA0013.jpg
# Downloading: IMG-20251210-WA0014.jpg
# Downloading: IMG-20251210-WA0017.jpg
# Downloading: IMG-20251210-WA0015.jpg
# Downloading: IMG-20251210-WA0011.jpg
# Downloading: IMG-20251210-WA0010.jpg
# Downloading: IMG-20251210-WA0012.jpg
# Downloading: IMG-20251210-WA0009.jpg
# Downloading: images.png
# Downloading: img_1260.jpg
# Downloading: ball_img_4241.jpg
# Downloading: ball_img_3293.jpg
# Downloading: ball_img_3460.jpg
# Downloading: ball_img_3184.jpg
# Downloading: ball_img_3173.jpg
# Downloading: ball_img_3279.jpg
# Downloading: ball_img_3271.jpg
# Downloading: ball_img_3276.jpg
# Downloading: ball_img_2639.jpg
# Downloading: ball_img_2427.jpg
# Downloading: ball_img_280.jpg
# Downloading: ball_img_1701.jpg
# Downloading: ball_img_1588.jpg
# Downloading: Screenshot 2024-03-16 121817.png
# Downloading: Screenshot 2024-03-16 120704.png
# Downloading: Screenshot 2024-03-16 121658.png
# Downloading: Screenshot 2024-03-16 121846.png
# Downloading: Screenshot 2024-03-16 120538.png
# Downloading: ball_img_1279.jpg
# Downloading: Screenshot 2024-03-16 120335.png
# Downloading: Screenshot 2024-03-16 120215.png
# Downloading: Screenshot 2024-03-16 120320.png
# Downloading: Screenshot 2024-03-16 120231.png
# Downloading: Screenshot 2024-03-16 120244.png
# Downloading: Screenshot 2024-03-16 115941.png
# Downloading: Screenshot 2024-03-16 115932.png
# Downloading: Screenshot 2024-03-16 120155.png
# Downloading: Screenshot 2024-03-16 120347.png
# Downloaded 49 images to /content/input_images
# Loading YOLO model (may download weights)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x-seg.pt to 'yolov8x-seg.pt': 100% ━━━━━━━━━━━━ 137.4MB 4.1MB/s 33.3s
# ball_classes (detected by name): [32, 34, 35]
# Processing 49 images...
#
# 0: 384x640 1 sports ball, 1 baseball bat, 3404.8ms
# Speed: 14.5ms preprocess, 3404.8ms inference, 42.2ms postprocess per image at shape (1, 3, 384, 640)
# IMG-20251210-WA0009.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0009.jpg
# IMG-20251210-WA0009.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0009.jpg
#
# 0: 448x640 1 sports ball, 3665.0ms
# Speed: 4.0ms preprocess, 3665.0ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
# IMG-20251210-WA0010.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0010.jpg
# IMG-20251210-WA0010.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0010.jpg
#
# 0: 512x640 1 sports ball, 5 baseball bats, 5089.2ms
# Speed: 3.8ms preprocess, 5089.2ms inference, 11.9ms postprocess per image at shape (1, 3, 512, 640)
# IMG-20251210-WA0011.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0011.jpg
# IMG-20251210-WA0011.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0011.jpg
#
# 0: 640x416 1 sports ball, 1 baseball bat, 3441.1ms
# Speed: 3.5ms preprocess, 3441.1ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 416)
# IMG-20251210-WA0012.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0012.jpg
# IMG-20251210-WA0012.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0012.jpg
#
# 0: 480x640 1 sports ball, 4 baseball bats, 1 baseball glove, 3803.2ms
# Speed: 3.6ms preprocess, 3803.2ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
# IMG-20251210-WA0013.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0013.jpg
# IMG-20251210-WA0013.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0013.jpg
#
# 0: 384x640 1 sports ball, 4 baseball bats, 1 baseball glove, 4006.3ms
# Speed: 3.0ms preprocess, 4006.3ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# IMG-20251210-WA0014.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0014.jpg
# IMG-20251210-WA0014.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0014.jpg
#
# 0: 416x640 1 sports ball, 3 baseball bats, 3280.8ms
# Speed: 3.4ms preprocess, 3280.8ms inference, 6.9ms postprocess per image at shape (1, 3, 416, 640)
# IMG-20251210-WA0015.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0015.jpg
# IMG-20251210-WA0015.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0015.jpg
#
# 0: 448x640 1 sports ball, 5 baseball bats, 1 baseball glove, 3529.4ms
# Speed: 3.6ms preprocess, 3529.4ms inference, 11.5ms postprocess per image at shape (1, 3, 448, 640)
# IMG-20251210-WA0016.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0016.jpg
# IMG-20251210-WA0016.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0016.jpg
#
# 0: 448x640 1 sports ball, 3 baseball bats, 1 baseball glove, 4533.6ms
# Speed: 3.4ms preprocess, 4533.6ms inference, 14.4ms postprocess per image at shape (1, 3, 448, 640)
# IMG-20251210-WA0017.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0017.jpg
# IMG-20251210-WA0017.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0017.jpg
#
# 0: 384x640 1 sports ball, 3 baseball bats, 1 baseball glove, 3035.8ms
# Speed: 3.1ms preprocess, 3035.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# IMG-20251210-WA0018.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0018.jpg
# IMG-20251210-WA0018.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0018.jpg
#
# 0: 448x640 1 sports ball, 3 baseball bats, 3529.3ms
# Speed: 3.9ms preprocess, 3529.3ms inference, 7.4ms postprocess per image at shape (1, 3, 448, 640)
# IMG-20251210-WA0019.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0019.jpg
# IMG-20251210-WA0019.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0019.jpg
#
# 0: 512x640 1 sports ball, 1 baseball bat, 1 baseball glove, 4482.8ms
# Speed: 3.8ms preprocess, 4482.8ms inference, 17.3ms postprocess per image at shape (1, 3, 512, 640)
# IMG-20251210-WA0020.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0020.jpg
# IMG-20251210-WA0020.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0020.jpg
#
# 0: 448x640 1 sports ball, 2 baseball bats, 4025.6ms
# Speed: 4.5ms preprocess, 4025.6ms inference, 11.1ms postprocess per image at shape (1, 3, 448, 640)
# IMG-20251210-WA0021.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0021.jpg
# IMG-20251210-WA0021.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0021.jpg
#
# 0: 384x640 1 sports ball, 2 baseball bats, 3045.2ms
# Speed: 3.0ms preprocess, 3045.2ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# IMG-20251210-WA0022.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0022.jpg
# IMG-20251210-WA0022.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0022.jpg
#
# 0: 448x640 1 sports ball, 1 baseball bat, 1 baseball glove, 3526.8ms
# Speed: 3.9ms preprocess, 3526.8ms inference, 10.3ms postprocess per image at shape (1, 3, 448, 640)
# IMG-20251210-WA0023.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0023.jpg
# IMG-20251210-WA0023.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0023.jpg
#
# 0: 416x640 1 sports ball, 5 baseball bats, 1 baseball glove, 4270.7ms
# Speed: 3.5ms preprocess, 4270.7ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
# IMG-20251210-WA0024.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0024.jpg
# IMG-20251210-WA0024.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0024.jpg
#
# 0: 384x640 1 sports ball, 1 baseball bat, 1 baseball glove, 3077.1ms
# Speed: 3.3ms preprocess, 3077.1ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
# IMG-20251210-WA0025.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0025.jpg
# IMG-20251210-WA0025.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0025.jpg
#
# 0: 352x640 1 sports ball, 4 baseball bats, 1 baseball glove, 2822.4ms
# Speed: 4.6ms preprocess, 2822.4ms inference, 8.7ms postprocess per image at shape (1, 3, 352, 640)
# IMG-20251210-WA0026.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0026.jpg
# IMG-20251210-WA0026.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0026.jpg
#
# 0: 416x640 1 sports ball, 2 baseball bats, 3478.6ms
# Speed: 2.9ms preprocess, 3478.6ms inference, 14.2ms postprocess per image at shape (1, 3, 416, 640)
# IMG-20251210-WA0027.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_IMG-20251210-WA0027.jpg
# IMG-20251210-WA0027.jpg: processed -> /content/output_images/removed_IMG-20251210-WA0027.jpg
#
# 0: 384x640 1 sports ball, 3799.3ms
# Speed: 5.1ms preprocess, 3799.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 115932.png: Hough fallback used
# Screenshot 2024-03-16 115932.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 115932.png
# Screenshot 2024-03-16 115932.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 115932.png
#
# 0: 384x640 1 sports ball, 1 baseball bat, 1 baseball glove, 3055.0ms
# Speed: 4.1ms preprocess, 3055.0ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 115941.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 115941.png
# Screenshot 2024-03-16 115941.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 115941.png
#
# 0: 384x640 1 sports ball, 2 baseball gloves, 3054.0ms
# Speed: 4.1ms preprocess, 3054.0ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 120155.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120155.png
# Screenshot 2024-03-16 120155.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120155.png
#
# 0: 384x640 1 sports ball, 4027.9ms
# Speed: 3.8ms preprocess, 4027.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 120215.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120215.png
# Screenshot 2024-03-16 120215.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120215.png
#
# 0: 384x640 1 sports ball, 2 baseball bats, 3013.6ms
# Speed: 4.1ms preprocess, 3013.6ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 120231.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120231.png
# Screenshot 2024-03-16 120231.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120231.png
#
# 0: 384x640 1 sports ball, 3038.9ms
# Speed: 4.0ms preprocess, 3038.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 120244.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120244.png
# Screenshot 2024-03-16 120244.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120244.png
#
# 0: 384x640 1 sports ball, 1 baseball bat, 3541.1ms
# Speed: 4.2ms preprocess, 3541.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 120320.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120320.png
# Screenshot 2024-03-16 120320.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120320.png
#
# 0: 384x640 1 sports ball, 1 baseball bat, 3296.0ms
# Speed: 4.2ms preprocess, 3296.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 120335.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120335.png
# Screenshot 2024-03-16 120335.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120335.png
#
# 0: 384x640 1 sports ball, 3033.4ms
# Speed: 4.0ms preprocess, 3033.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 120347.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120347.png
# Screenshot 2024-03-16 120347.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120347.png
#
# 0: 384x640 1 sports ball, 1 baseball bat, 3035.9ms
# Speed: 3.9ms preprocess, 3035.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Screenshot 2024-03-16 120538.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120538.png
# Screenshot 2024-03-16 120538.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120538.png
#
# 0: 288x640 1 sports ball, 1 baseball bat, 1 baseball glove, 3302.2ms
# Speed: 3.0ms preprocess, 3302.2ms inference, 8.8ms postprocess per image at shape (1, 3, 288, 640)
# Screenshot 2024-03-16 120704.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 120704.png
# Screenshot 2024-03-16 120704.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 120704.png
#
# 0: 352x640 1 sports ball, 2839.3ms
# Speed: 4.3ms preprocess, 2839.3ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
# Screenshot 2024-03-16 121658.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 121658.png
# Screenshot 2024-03-16 121658.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 121658.png
#
# 0: 448x640 1 sports ball, 3559.5ms
# Speed: 4.7ms preprocess, 3559.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Screenshot 2024-03-16 121817.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 121817.png
# Screenshot 2024-03-16 121817.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 121817.png
#
# 0: 288x640 2 baseball bats, 2440.2ms
# Speed: 3.1ms preprocess, 2440.2ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 640)
# Screenshot 2024-03-16 121846.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_Screenshot 2024-03-16 121846.png
# Screenshot 2024-03-16 121846.png: processed -> /content/output_images/removed_Screenshot 2024-03-16 121846.png
#
# 0: 384x640 1 sports ball, 1 baseball bat, 2 baseball gloves, 3836.5ms
# Speed: 3.6ms preprocess, 3836.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_1279.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_1279.jpg
# ball_img_1279.jpg: processed -> /content/output_images/removed_ball_img_1279.jpg
#
# 0: 384x640 1 sports ball, 3 baseball bats, 1 baseball glove, 3102.6ms
# Speed: 5.7ms preprocess, 3102.6ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_1588.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_1588.jpg
# ball_img_1588.jpg: processed -> /content/output_images/removed_ball_img_1588.jpg
#
# 0: 384x640 1 sports ball, 3057.2ms
# Speed: 3.6ms preprocess, 3057.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_1701.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_1701.jpg
# ball_img_1701.jpg: processed -> /content/output_images/removed_ball_img_1701.jpg
#
# 0: 384x640 1 sports ball, 3 baseball bats, 3858.7ms
# Speed: 3.0ms preprocess, 3858.7ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_2427.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_2427.jpg
# ball_img_2427.jpg: processed -> /content/output_images/removed_ball_img_2427.jpg
#
# 0: 384x640 1 sports ball, 1 baseball bat, 1 baseball glove, 3192.5ms
# Speed: 2.9ms preprocess, 3192.5ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_2639.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_2639.jpg
# ball_img_2639.jpg: processed -> /content/output_images/removed_ball_img_2639.jpg
#
# 0: 384x640 1 baseball bat, 3058.5ms
# Speed: 3.0ms preprocess, 3058.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_280.jpg: Hough fallback used
# ball_img_280.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_280.jpg
# ball_img_280.jpg: processed -> /content/output_images/removed_ball_img_280.jpg
#
# 0: 384x640 2 sports balls, 4 baseball bats, 3076.8ms
# Speed: 2.8ms preprocess, 3076.8ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_3173.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_3173.jpg
# ball_img_3173.jpg: processed -> /content/output_images/removed_ball_img_3173.jpg
#
# 0: 384x640 2 sports balls, 3 baseball bats, 4018.3ms
# Speed: 2.8ms preprocess, 4018.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_3184.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_3184.jpg
# ball_img_3184.jpg: processed -> /content/output_images/removed_ball_img_3184.jpg
#
# 0: 384x640 (no detections), 3058.0ms
# Speed: 3.0ms preprocess, 3058.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_3271.jpg: Hough fallback used
# ball_img_3271.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_3271.jpg
# ball_img_3271.jpg: processed -> /content/output_images/removed_ball_img_3271.jpg
#
# 0: 384x640 1 baseball bat, 1 baseball glove, 3052.7ms
# Speed: 2.9ms preprocess, 3052.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_3276.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_3276.jpg
# ball_img_3276.jpg: processed -> /content/output_images/removed_ball_img_3276.jpg
#
# 0: 384x640 (no detections), 3175.7ms
# Speed: 2.9ms preprocess, 3175.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_3279.jpg: Hough fallback used
# ball_img_3279.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_3279.jpg
# ball_img_3279.jpg: processed -> /content/output_images/removed_ball_img_3279.jpg
#
# 0: 384x640 1 sports ball, 3 baseball bats, 3907.2ms
# Speed: 2.8ms preprocess, 3907.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_3293.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_3293.jpg
# ball_img_3293.jpg: processed -> /content/output_images/removed_ball_img_3293.jpg
#
# 0: 384x640 1 sports ball, 3 baseball bats, 1 baseball glove, 3095.7ms
# Speed: 2.9ms preprocess, 3095.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_3460.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_3460.jpg
# ball_img_3460.jpg: processed -> /content/output_images/removed_ball_img_3460.jpg
#
# 0: 384x640 3 baseball bats, 3070.4ms
# Speed: 2.9ms preprocess, 3070.4ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# ball_img_4241.jpg: Hough fallback used
# ball_img_4241.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_ball_img_4241.jpg
# ball_img_4241.jpg: processed -> /content/output_images/removed_ball_img_4241.jpg
#
# 0: 384x640 2 sports balls, 1 baseball bat, 2 baseball gloves, 3733.1ms
# Speed: 2.9ms preprocess, 3733.1ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
# images.png: Hough fallback used
# images.png: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_images.png
# images.png: processed -> /content/output_images/removed_images.png
#
# 0: 384x640 1 sports ball, 3 baseball bats, 3 baseball gloves, 3329.0ms
# Speed: 4.0ms preprocess, 3329.0ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
# img_1260.jpg: saved to Drive path /content/drive/MyDrive/ball_removed_results/removed_img_1260.jpg
# img_1260.jpg: processed -> /content/output_images/removed_img_1260.jpg
# Zipping outputs...
# Created ZIP: /content/removed_images.zip
# Starting browser download (you will be prompted)...
# All done. Processed images are saved locally in /content/output_images and attempts to save to Drive folder: /content/drive/MyDrive/ball_removed_results
